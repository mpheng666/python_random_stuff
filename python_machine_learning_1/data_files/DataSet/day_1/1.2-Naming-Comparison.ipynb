# %% [markdown]
# <center>
#   <a href="1.1-Arithmetic-Assignment.ipynb" target=_self>Previous Page</a> | <a href="./">Content Page</a> | <a href="1.3-Boolean-Function .ipynb">Next Page</a></center>
# </center>

# %% [markdown]
# # 1.2 Naming and Comparison

# %% [markdown]
# ## 1.2.1 Naming Variables
#
#
# Examples of **valid** and **invalid** variables names:
#
# | Valid               |  Invalid                          |
# |---------------------|-----------------------------------|
# | spam    | 4spam              |
# | not_spam     | not spam             |     |
# | _balance    | not-spam |

# %% [markdown]
# We cannot use **reserved words** such as *print*:

# %%
print("abc")
# Out:
# abc

# %%
#print is a reserved word, it should not be assign any value to a reserved word.
print=4

# %%
print
# Out:
# 4

# %%
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-2223c92d0779> in <module>()
# ----> 1 print(print)
#
# TypeError: 'int' object is not callable

# %%
a=4
a
# Out:
# 4

# %% [markdown]
# ##### We have messed it up!  The print is no longer a `python function`

# %%
print("abc")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-afcc53b9e645> in <module>()
# ----> 1 print("abc")
#
# TypeError: 'int' object is not callable

# %%
print
# Out:
# 4

# %% [markdown]
# ##### Restart the kernel by going to Running and "Shutdown"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
false=1  #not recommended whether it is lower-case or uppercase (as the reserved words)
print (false)
# Out:
# 1

# %%
False=0  #not recommended
print (False)
# Out:
#   File "<ipython-input-7-0ebff7c9a13b>", line 1
#     False=0  #not recommended
#                              ^
# SyntaxError: can't assign to keyword

# %%
True==false
# Out:
# True

# %% [markdown]
# ##### Below it is working fine (mistakenly) in Python 2

# %%
#In Python 2, it can be assigned.

False=5  #not recommended

print (False)
# Out:
#   File "<ipython-input-6-6216aeeaf3c6>", line 3
#     False=5  #not recommended
#                              ^
# SyntaxError: can't assign to keyword

# %%
True==False
# Out:
# True

# %% [markdown]
# ## 1.2.1 Comparison Operations
#
# `=` is not the same as `==`. <br>
# `=` is an assignment where `==` is a comparison operator.
#
# Another type of operation which can be very useful is comparison of different values.
# For this, Python implements standard comparison operators, which return Boolean values ``True`` and ``False``.
# The comparison operations are listed in the following table:
#
# | Operation     | Description                       || Operation     | Description                          |
# |---------------|-----------------------------------||---------------|--------------------------------------|
# | ``a == b``    | ``a`` equal to ``b``              || ``a != b``    | ``a`` not equal to ``b``             |
# | ``a < b``     | ``a`` less than ``b``             || ``a > b``     | ``a`` greater than ``b``             |
# | ``a <= b``    | ``a`` less than or equal to ``b`` || ``a >= b``    | ``a`` greater than or equal to ``b`` |
#
# These comparison operators can be combined with the arithmetic and bitwise operators to express a virtually limitless range of tests for the numbers.
# <br><br>For example, we can check if a number is odd by checking that the modulus with 2 returns 1:

# %%
# %=Modulus i.e., Reminder
# 25 is odd
25 % 2 == 1
# Out:
# True

# %%
# 66 is odd
66 % 2 == 1
# Out:
# False

# %%
# check if a is between 15 and 30
a = 25
15 < a < 30
# Out:
# True

# %% [markdown]
# ##### Preview of `if` statement

# %%
if 25 % 2 ==1 :
    print("odd")
else:
    print("even")
# Out:
# odd

# %%
if 24 % 2 ==1 :
    print("odd")
else:
    print("even")
# Out:
# even

# %% [markdown]
# Boolean `True` equals to number **1** and `False` equals to **0**

# %%
if True==1:
    print ("True = 1")
else:
    print ("True equals to something else than 1")
# Out:
# True = 1

# %%
if False==0:
    print ("False = 0")
else:
    print ("False equals to something else than 0")
# Out:
# False = 0

# %% [markdown]
# # Exercise 1.2.1
# * Assign 5 to a variable called `type`
# * Evaluate the value of `type` using `print(type)`
# * Assign 10 to `k`
# * Evaluate the value of `k` using `print(k)`
# * Evaluate the `type` of `k` variable using `type(k)`
# * Anything Wrong?

# %%
type=5

# %%
print(____)
# Out:
# 5

# %%
k=___

# %%
print(k)

# %%
type(k)
# Out:
# str

# %% [markdown]
# #  Exercise 1.2.2
# * Restart the kernel clicking `Kernel` and `Restart`
# * Assign 10 to `k`
# * Evaluate the value of `k` using `print(k)`
# * Evaluate the `type` of `k` variable using `type(k)`
# * Anything Wrong?

# %%
k=10

# %%
print(k)
# Out:
# 10

# %%
type(k)
# Out:
# int

# %%
r = [122, 24.6]
r.append([12, 23])
print(r)
# Out:
# [122, 24.6, [12, 23]]

# %%
print(type(r))
# Out:
# <class 'list'>

# %%
print(r)
# Out:
# [122, 24.6, [12, 23]]

# %%
r.append(k)
r
# Out:
# [122, 24.6, [12, 23], 10]

# %% [markdown]
# <center>
#   <a href="1.1-Arithmetic-Assignment.ipynb">Previous Page</a> | <a href="./">Content Page</a> | <a href="1.3-Boolean-Function .ipynb">Next Page</a></center>
# </center>
