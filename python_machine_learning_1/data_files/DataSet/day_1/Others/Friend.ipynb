# %% [markdown]
# # Impress my Friend about my knowledge in Badminton

# %% [markdown]
# Import and alias Pandas:

# %%
import pandas as pd

# %% [markdown]
# Access the table from the link, download, and extract the dataset out of the website. If you're having issues with this, look carefully at the sample code provided in the class:

# %%
df=pd.read_html('http://bwfbadminton.com/rankings/2/bwf-world-rankings/6/men-s-singles/2018/10/?rows=100&page_no=1', index_col=None)

# %%
#getting the first table in the website
df[0]
# Out:
#       RANK COUNTRY                    PLAYER  CHANGE +/- WIN - LOSE  \
# 0      1.0     DEN            Viktor AXELSEN         0.0  274 - 107
# 1      NaN     NaN                       NaN         NaN        NaN
# 2      2.0     MAS             LEE Chong Wei         0.0  689 - 132
# 3      NaN     NaN                       NaN         NaN        NaN
# 4      3.0     IND          KIDAMBI Srikanth         0.0   178 - 88
# 5      NaN     NaN                       NaN         NaN        NaN
# 6      4.0     KOR                SON Wan Ho         1.0  297 - 161
# 7      NaN     NaN                       NaN         NaN        NaN
# 8      5.0     CHN                 CHEN Long         1.0   365 - 83
# 9      NaN     NaN                       NaN         NaN        NaN
# 10     6.0     CHN                  SHI Yuqi         0.0   133 - 48
# 11     NaN     NaN                       NaN         NaN        NaN
# 12     7.0     CHN                   LIN Dan         1.0   619 - 94
# ...

# %%
bad=df[0].dropna(axis=0, thresh=4)

# %%
bad.head(4)
# Out:
#    RANK COUNTRY            PLAYER  CHANGE +/- WIN - LOSE    PRIZE MONEY  \
# 0   1.0     DEN    Viktor AXELSEN         0.0  274 - 107    $474,552.00
# 2   2.0     MAS     LEE Chong Wei         0.0  689 - 132  $1,778,882.50
# 4   3.0     IND  KIDAMBI Srikanth         0.0   178 - 88    $393,977.50
# 6   4.0     KOR        SON Wan Ho         1.0  297 - 161    $386,945.00
#
#   POINTS                / TOURNAMENTS  BREAKDOWN
# 0                         79,580 / 13        NaN
# 2                         76,924 / 14        NaN
# 4                         75,695 / 12        NaN
# 6                         73,970 / 19        NaN

# %%
bad.columns
# Out:
# Index(['RANK', 'COUNTRY', 'PLAYER', 'CHANGE +/-', 'WIN - LOSE', 'PRIZE MONEY',
#        'POINTS                / TOURNAMENTS', 'BREAKDOWN'],
#       dtype='object')

# %%
bad[bad.COUNTRY=='DEN']
# Out:
#      RANK COUNTRY                            PLAYER  CHANGE +/- WIN - LOSE  \
# 0     1.0     DEN                    Viktor AXELSEN         0.0  274 - 107
# 32   17.0     DEN                   Anders ANTONSEN         0.0   139 - 35
# 40   21.0     DEN  Hans-Kristian Solberg VITTINGHUS         2.0  304 - 172
# 72   37.0     DEN                      Rasmus GEMKE         0.0    78 - 30
# 92   47.0     DEN                        Emil HOLST         1.0  200 - 111
# 144  73.0     DEN                   Jan O JORGENSEN         1.0  389 - 193
# 146  74.0     DEN                         Kim BRUUN         5.0   165 - 91
# 150  76.0     DEN                   Victor SVENDSEN         1.0   108 - 41
#
#      PRIZE MONEY POINTS                / TOURNAMENTS  BREAKDOWN
# 0    $474,552.00                         79,580 / 13        NaN
# 32    $50,420.25                         48,937 / 16        NaN
# 40   $198,824.10                         43,650 / 17        NaN
# ...

# %%
bad[bad.COUNTRY=='CHN']
# Out:
#      RANK COUNTRY         PLAYER  CHANGE +/- WIN - LOSE    PRIZE MONEY  \
# 8     5.0     CHN      CHEN Long         1.0   365 - 83  $1,074,827.50
# 10    6.0     CHN       SHI Yuqi         0.0   133 - 48    $162,742.50
# 12    7.0     CHN        LIN Dan         1.0   619 - 94    $905,755.00
# 46   24.0     CHN    TIAN Houwei         0.0   139 - 80    $234,875.00
# 54   28.0     CHN       QIAO Bin         0.0    89 - 44     $87,007.50
# 74   38.0     CHN  HUANG Yuxiang         0.0    77 - 53     $54,182.50
# 138  70.0     CHN   ZHAO Junpeng         0.0    68 - 29     $22,780.00
#
#     POINTS                / TOURNAMENTS  BREAKDOWN
# 8                           73,636 / 13        NaN
# 10                          70,093 / 15        NaN
# 12                          66,726 / 13        NaN
# 46                          39,770 / 11        NaN
# 54                          38,174 / 12        NaN
# 74                          34,350 / 13        NaN
# ...
