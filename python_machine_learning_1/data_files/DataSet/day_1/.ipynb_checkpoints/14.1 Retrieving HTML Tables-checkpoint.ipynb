# %% [markdown]
# <center>
#   <a href="13.1%20ODBC.ipynb">Previous Page</a> | <a href="./">Content Page</a> | <a href="14.1.A. Retrieving HTML -Badminton.ipynb">Impress yourfriend: Activity</a></center>

# %% [markdown]
# # 14.1 Retrieving HTML Tables

# %%
import pandas as pd

# %%
URL = 'https://sg.finance.yahoo.com/currencies'

# %%
df_backup=pd.read_html(URL,index_col=None)
df=df_backup[0]

# %%
df
# Out:
#       Symbol     Name   Last price     Change   % change  52-week range  \
# 0      SGD=X  USD/SGD      1.36922   -0.00379  -0.27604%            NaN
# 1   SGDMYR=X  SGD/MYR      3.04240    0.00210     +0.07%            NaN
# 2   GBPSGD=X  GBP/SGD      1.80130    0.00430     +0.24%            NaN
# 3   EURSGD=X  EUR/SGD      1.57190    0.00390     +0.25%            NaN
# 4   SGDJPY=X  SGD/JPY     82.77200    0.19000     +0.23%            NaN
# 5   SGDHKD=X  SGD/HKD      5.71600    0.01400     +0.25%            NaN
# 6   SGDIDR=X  SGD/IDR  10648.15400 -133.48300     -1.24%            NaN
# 7   SGDCNY=X  SGD/CNY      5.05110    0.01390     +0.28%            NaN
# 8   SGDPHP=X  SGD/PHP     38.51000   -0.08000     -0.21%            NaN
# 9   SGDTHB=X  SGD/THB     23.95290   -0.03670     -0.15%            NaN
# 10  SGDINR=X  SGD/INR     52.95400   -0.18400     -0.35%            NaN
# 11  SGDVND=X  SGD/VND  17001.60000   47.60000     +0.28%            NaN
# 12  SGDKRW=X  SGD/KRW    815.54000    0.17000     +0.02%            NaN
# 13  AUDSGD=X  AUD/SGD      0.99720    0.00410     +0.41%            NaN
# 14  NZDSGD=X  NZD/SGD      0.92860    0.00380     +0.41%            NaN
# 15  GBPUSD=X  GBP/USD      1.31563    0.00620  +0.47363%            NaN
# 16     JPY=X  USD/JPY    113.33800   -0.07400    -0.065%            NaN
# 17     HKD=X  USD/HKD      7.83035   -0.00094  -0.01200%            NaN
# 18     MYR=X  USD/MYR      4.16400   -0.00900    -0.216%            NaN
# 19     INR=X  USD/INR     72.48900   -0.46000    -0.631%            NaN
# 20     CNY=X  USD/CNY      6.91730    0.00020   +0.0029%            NaN
# 21     PHP=X  USD/PHP     52.72000   -0.26000     -0.49%            NaN
# 22     IDR=X  USD/IDR  14575.00000 -225.00000     -1.52%            NaN
# 23     THB=X  USD/THB     32.78000   -0.13000     -0.40%            NaN
# 24     CHF=X  USD/CHF      0.99818   -0.00458  -0.45675%            NaN
# 25     MXN=X  USD/MXN     19.84470    0.12750   +0.6466%            NaN
# 26  AUDUSD=X  AUD/USD      0.72810    0.00450   +0.6189%            NaN
# 27  NZDUSD=X  NZD/USD      0.67860    0.00470   +0.6922%            NaN
# 28     KRW=X  USD/KRW   1117.05000   -2.75000     -0.25%            NaN
# 29     VND=X  USD/VND  23320.00000   -5.00000     -0.02%            NaN
# 30     CAD=X  USD/CAD      1.30900   -0.00300    -0.241%            NaN
# 31  EURJPY=X  EUR/JPY    130.11100    0.59500     +0.46%            NaN
# 32  GBPJPY=X  GBP/JPY    149.11700    0.61800     +0.42%            NaN
# 33  EURGBP=X  EUR/GBP      0.87252    0.00052     +0.06%            NaN
# 34  EURSEK=X  EUR/SEK     10.32611   -0.00529     -0.05%            NaN
# 35  EURCHF=X  EUR/CHF      1.14588    0.00069     +0.06%            NaN
# 36  EURHUF=X  EUR/HUF    321.59000   -0.04000     -0.01%            NaN
# 37  EURJPY=X  EUR/JPY    130.11100    0.59500     +0.46%            NaN
#
#     Day chart
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 32        NaN
# 33        NaN
# 34        NaN
# 35        NaN
# 36        NaN
# 37        NaN

# %%
df.columns
# Out:
# Index(['Symbol', 'Name', 'Last price', 'Change', '% change', '52-week range',
#        'Day chart'],
#       dtype='object')

# %%
df.loc[:, ['Name', 'Last price']]
# Out:
#        Name   Last price
# 0   USD/SGD      1.36922
# 1   SGD/MYR      3.04240
# 2   GBP/SGD      1.80130
# 3   EUR/SGD      1.57190
# 4   SGD/JPY     82.77200
# 5   SGD/HKD      5.71600
# 6   SGD/IDR  10648.15400
# 7   SGD/CNY      5.05110
# 8   SGD/PHP     38.51000
# 9   SGD/THB     23.95290
# 10  SGD/INR     52.95400
# 11  SGD/VND  17001.60000
# 12  SGD/KRW    815.54000
# 13  AUD/SGD      0.99720
# 14  NZD/SGD      0.92860
# 15  GBP/USD      1.31563
# 16  USD/JPY    113.33800
# 17  USD/HKD      7.83035
# 18  USD/MYR      4.16400
# 19  USD/INR     72.48900
# 20  USD/CNY      6.91730
# 21  USD/PHP     52.72000
# 22  USD/IDR  14575.00000
# 23  USD/THB     32.78000
# 24  USD/CHF      0.99818
# 25  USD/MXN     19.84470
# 26  AUD/USD      0.72810
# 27  NZD/USD      0.67860
# 28  USD/KRW   1117.05000
# 29  USD/VND  23320.00000
# 30  USD/CAD      1.30900
# 31  EUR/JPY    130.11100
# 32  GBP/JPY    149.11700
# 33  EUR/GBP      0.87252
# 34  EUR/SEK     10.32611
# 35  EUR/CHF      1.14588
# 36  EUR/HUF    321.59000
# 37  EUR/JPY    130.11100

# %% [markdown]
# <center>
#   <a href="1.13.ODBC.ipynb">Previous Page</a> | <a href="./">Content Page</a> | <a href="14.1.A. Retrieving HTML -Badminton.ipynb">Impress yourfriend: Activity</a></center>
