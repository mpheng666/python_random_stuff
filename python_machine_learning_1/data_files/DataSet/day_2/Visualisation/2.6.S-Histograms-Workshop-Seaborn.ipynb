# %% [markdown]
# # 2.6.S-Histograms Workshop-Seaborn

# %% [markdown]
# Plot a Histogram similar to the below:

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![Resale Price Histogram](Histogram_workshop.png1)

# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
df = pd.read_csv("resale-sample-regression.csv", index_col=0)

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price',
#        'Region'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(15, 5))

# %%
#plt.title("Resale Price Histogram")
#plt.ylabel("Number of Transaction")
