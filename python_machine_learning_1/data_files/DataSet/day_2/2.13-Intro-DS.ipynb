# %% [markdown]
# <center>
#   <a href="2.12-Scatterplot.ipynb">Previous Page</a> | <a href="./">Content Page</a> | <a href="2.14-Example of Logistic Regression.ipynb">Example of Logistic Regression</a></center>
# </center>

# %% [markdown]
# <H2>
#
# 1. (2.13.1) Differences between Supervised and Unsupervised Learning
# 1. (2.13.2) Differences between Classification and Regression
# -  (2.13.3) Train, Test, Split
# -  (2.12.4) Cross Validation
# -  (2.12.5) How to evaluate the results (Performance Metrics)
# -  (2.12.6) Scikit-Learn

# %% [markdown]
# #### Resources

# %% [markdown]
# #### Topic A:Supervised and Unsupervised

# %% [markdown]
# *Reference 1:*
# https://www.quora.com/What-is-the-difference-between-supervised-and-unsupervised-learning-algorithms
# <br>Local trim data: [Local Trim data](resources\html\What is the difference between supervised and unsupervised learning algorithms_ - Quora.html)

# %% [markdown]
# Others:
# https://machinelearningmastery.com/supervised-and-unsupervised-machine-learning-algorithms/

# %% [markdown]
# #### Topic B: Classification and Regression

# %% [markdown]
# *Reference 1:*
# https://medium.com/simple-ai/classification-versus-regression-intro-to-machine-learning-5-5566efd4cb83
#
# Please go directly to the link

# %% [markdown]
# *Reference 2:* https://machinelearningmastery.com/classification-versus-regression-in-machine-learning/
# <br>Local trim data: [Local Trim data](resources\html\Difference Between Classification and Regression in Machine Learning.html)

# %% [markdown]
# #### Topic C: Train, Test, and Split

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %% [markdown]
# Others:https://towardsdatascience.com/train-test-split-and-cross-validation-in-python-80b61beca4b6
# https://datascience.stackexchange.com/questions/15804/which-train-test-split-performs-better-5050-or-6040

# %% [markdown]
# #### Topic D: Cross-validation

# %% [markdown]
# https://www.kaggle.com/dansbecker/cross-validation

# %% [markdown]
# Others:https://towardsdatascience.com/train-test-split-and-cross-validation-in-python-80b61beca4b6

# %% [markdown]
# #### Topic E: Performance Metrics

# %% [markdown]
# http://scikit-learn.org/stable/modules/model_evaluation.html

# %% [markdown]
# *Classification Metrics*

# %% [markdown]
# https://machinelearningmastery.com/confusion-matrix-machine-learning/

# %% [markdown]
# http://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html

# %% [markdown]
# *Regression*

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html

# %% [markdown]
# https://towardsdatascience.com/linear-regression-in-python-9a1f5f000606

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Topic F: Scikit

# %% [markdown]
# http://scikit-learn.org

# %% [markdown]
# ### Other Useful Links:

# %% [markdown]
# Intro to Machine Learning (Python: Jupyter Notebook)
# https://www.youtube.com/watch?time_continue=6&v=G7fPB4OHkys

# %% [markdown]
# <center>
#   <a href="2.11-Scatterplot.ipynb">Previous Page</a> | <a href="./">Content Page</a> | <a href="2.14-Example of Logistic Regression.ipynb">Example of Logistic Regression</a></center>
# </center>
