# %% [markdown]
# ## Basics of Matplotlib and Seaborn - data visualization with Python

# %%
people = ['Ann','Brandon','Chen','David','Emily','Farook',
          'Gagan','Hamish','Imran','Julio','Katherine','Lily']
age = [21,12,32,45,37,18,28,52,5,40,48,15]
weight = [55,35,77,68,70,60,72,69,18,65,82,48]
height = [160,135,170,165,173,168,175,159,105,171,155,158]

import matplotlib.pyplot as plt
# plt.scatter(age, height)
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
plt.title("simple 3D scatter plot")
 
# show plot
ax.scatter3D(age, height, weight, color = "green")
plt.show()

# %%
plt.scatter(age, weight)
plt.show()

# %%
# Set figure size
plt.figure(figsize=(8,6))

# Add a main title
plt.title("Plot of Age vs. Height (in cms)\n",fontsize=20, fontstyle='italic')

# X- and Y-label with fontsize
plt.xlabel("Age (years)",fontsize=16)
plt.ylabel("Height (cms)",fontsize=16)

# Turn on grid
plt.grid (True)

# Set Y-axis limit
plt.ylim(100,200)

# X- and Y-axis ticks customization with fontsize and placement
plt.xticks([i*5 for i in range(15)],fontsize=15)
plt.yticks(fontsize=15)

# Main plotting function with choice of color, marker size, and marker edge color
plt.scatter(x=age,y=height,c='orange',s=150,edgecolors='k')

# Adding bit of text to the plot
plt.text(x=15,y=105,s="Height increaes up to around \n20 years and then tapers off",fontsize=15, 
         rotation=30, linespacing=2)
plt.text(x=22,y=185,s="Nobody has a height beyond 180 cm",fontsize=15)

# Adding a vertical line
plt.vlines(x=20,ymin=100,ymax=180,linestyles='dashed',color='blue',lw=3)

# Adding a horizontal line
plt.hlines(y=180,xmin=0,xmax=55,linestyles='dashed',color='red',lw=3)

# Adding a legend
plt.legend(['Height in cms'],loc=2,fontsize=14)

# Final show method
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16, fontstyle='italic')
# Main plot function 'bar'
plt.bar(x=people,height=weight, width=0.6,color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()

# %%
import numpy as np
plt.figure(figsize=(7,5))
# Main plot function 'hist'
plt.hist(weight,color='red',edgecolor='k', alpha=0.75,bins=50)
plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
import numpy as np
plt.figure(figsize=(8,5))
# Main plot function 'hist'
plt.hist(height,color='red',edgecolor='k', alpha=0.9,bins=10)
plt.title("Histogram of patient height",fontsize=18)
plt.xlabel("height in kgs",fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
import numpy as np
plt.figure(figsize=(8,5))
# Main plot function 'hist'
plt.hist(weight,color='red',edgecolor='k', alpha=0.9,bins=10)
plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("weight in kgs",fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
data_size = 30
days = np.arange(1,data_size+1)
candidate_A = 50+days*0.07+2*np.random.randn(data_size)
candidate_B = 50-days*0.1+3*np.random.randn(data_size)
# Determine the minimum and maximum of stock prices
ymin = min(candidate_A.min(),candidate_B.min())
ymax = max(candidate_A.max(),candidate_B.max())
# Set style
plt.style.use('seaborn')

plt.figure(figsize=(12,5))
plt.title("Time series plot of poll percentage over a month\n",fontsize=20, fontstyle='italic')
plt.xlabel("Days",fontsize=16)
plt.ylabel("Poll percentage (%)",fontsize=16)
# plt.ylim(ymin*0.98,ymax*1.02)
plt.xticks([i for i in range(data_size)],fontsize=14)
plt.yticks(fontsize=15)

# Main plotting function - plot (note markersize, lw (linewidth) arguments)
plt.plot(days,candidate_A,'o-',markersize=10,c='blue',lw=2)
plt.plot(days,candidate_B,'^-',markersize=10,c='green',lw=2)

plt.legend(['Poll percentage of candidate A (%)', 'Poll percentage of candidate B (%)'],loc=2,fontsize=14)
plt.show()

# %%
# plt.style.use('ggplot')
# Note how to convert default numerical x-axis ticks to the list of string by passing two lists 
plt.boxplot(x=[candidate_A,candidate_B],showmeans=True)
plt.grid(True)
plt.xticks([1,2],['Candidate A','Candidate B'])
#plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ## Pandas DataFrames support some visualizations directly!

# %% [markdown]
# import pandas as pd
# #!wget "https://raw.githubusercontent.com/tirthajyoti/Stats_data_science_ValleyML/master/Notebooks/Data/wine.data.csv"
# #!wget "https://raw.githubusercontent.com/tirthajyoti/Stats_data_science_ValleyML/master/Notebooks/Data/Height_Weight.xlsx"
#
# !md Data
# !copy wine_r2_t.csv data\

# %%
df = pd.read_csv('wine_r2_t.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
import matplotlib as mpl
# mpl.rcParams.update(mpl.rcParamsDefault)
# Scatter plot
# df.plot.scatter('alcohol','pH')
x_axis = 'pH'
y_axis = 'residual sugar'
df.plot.scatter(x_axis, y_axis)
plt.show()

# %%
df[x_axis].plot.hist(bins=20,figsize=(5,5),edgecolor='k')
plt.xlabel(x_axis)
plt.show()

# %%
#Seaborn - advanced statistical visualizations
import seaborn as sns

# %%
sns.regplot(x=x_axis,y=y_axis,data=df)
plt.show()

# %%
sns.lmplot(x=x_axis,y=y_axis,hue='quality',data=df)
plt.show()

# %%
# Correlation matrix and heatmap
import numpy as np
corr_mat=np.corrcoef(df,rowvar=False)
corr_mat.shape
# Out:
# (12, 12)

# %%
corr_df = pd.DataFrame(corr_mat,columns=df.columns,index=df.columns)
print(np.round(corr_mat,3))
# Out:
# [[ 1.    -0.256  0.672  0.115  0.094 -0.154 -0.113  0.668 -0.683  0.183
#   -0.062  0.124]
#  [-0.256  1.    -0.552  0.002  0.061 -0.011  0.076  0.022  0.235 -0.261
#   -0.202 -0.391]
#  [ 0.672 -0.552  1.     0.144  0.204 -0.061  0.036  0.365 -0.542  0.313
#    0.11   0.226]
#  [ 0.115  0.002  0.144  1.     0.056  0.187  0.203  0.355 -0.086  0.006
#    0.042  0.014]
#  [ 0.094  0.061  0.204  0.056  1.     0.006  0.047  0.201 -0.265  0.371
#   -0.221 -0.129]
#  [-0.154 -0.011 -0.061  0.187  0.006  1.     0.668 -0.022  0.07   0.052
#   -0.069 -0.051]
#  [-0.113  0.076  0.036  0.203  0.047  0.668  1.     0.071 -0.066  0.043
#   -0.206 -0.185]
#  [ 0.668  0.022  0.365  0.355  0.201 -0.022  0.071  1.    -0.342  0.149
#   -0.496 -0.175]
#  [-0.683  0.235 -0.542 -0.086 -0.265  0.07  -0.066 -0.342  1.    -0.197
#    0.206 -0.058]
#  [ 0.183 -0.261  0.313  0.006  0.371  0.052  0.043  0.149 -0.197  1.
#    0.094  0.251]
#  [-0.062 -0.202  0.11   0.042 -0.221 -0.069 -0.206 -0.496  0.206  0.094
#    1.     0.476]
#  [ 0.124 -0.391  0.226  0.014 -0.129 -0.051 -0.185 -0.175 -0.058  0.251
#    0.476  1.   ]]

# %%
# sns.heatmap(corr_df,linewidth=1,cmap='plasma')
sns.heatmap(corr_df,linewidth=1,cmap='gray')
plt.show()

# %%
sns.pairplot(df)
