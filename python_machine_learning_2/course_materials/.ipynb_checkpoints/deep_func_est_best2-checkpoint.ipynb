# %% [markdown]
# # Deep Learning for Function Estimation

# %%
# CNN version
# Regression Example With wine dataset ...
import pandas as pd
from pandas import read_csv
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense 
from tensorflow.keras.layers import Conv1D 
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split 
import numpy as np
import matplotlib.pyplot as plt

# %%
# load dataset
dataframe = read_csv("wine_r2_t_noheader.csv" , header=None)
dataset = dataframe.values

# split into input (X) and output (Y) variables
X = dataset[:,0:11]
Y = dataset[:,11]

print(X.shape)
X = X.reshape(X.shape[0], X.shape[1], 1)
print(X.shape)
# Out:
# (1599, 11)
# (1599, 11, 1)

# %%
print(dataset.shape)
dataframe.describe()
# Out:
# (1599, 12)
#                 0            1            2            3            4   \
# count  1599.000000  1599.000000  1599.000000  1599.000000  1599.000000
# mean      8.319637     0.527821     0.270976     2.538806     0.087467
# std       1.741096     0.179060     0.194801     1.409928     0.047065
# min       4.600000     0.120000     0.000000     0.900000     0.012000
# 25%       7.100000     0.390000     0.090000     1.900000     0.070000
# 50%       7.900000     0.520000     0.260000     2.200000     0.079000
# 75%       9.200000     0.640000     0.420000     2.600000     0.090000
# max      15.900000     1.580000     1.000000    15.500000     0.611000
#
#                 5            6            7            8            9   \
# count  1599.000000  1599.000000  1599.000000  1599.000000  1599.000000
# mean     15.874922    46.467792     0.996747     3.311113     0.658149
# std      10.460157    32.895324     0.001887     0.154386     0.169507
# min       1.000000     6.000000     0.990070     2.740000     0.330000
# 25%       7.000000    22.000000     0.995600     3.210000     0.550000
# 50%      14.000000    38.000000     0.996750     3.310000     0.620000
# 75%      21.000000    62.000000     0.997835     3.400000     0.730000
# max      72.000000   289.000000     1.003690     4.010000     2.000000
#
#                 10           11
# count  1599.000000  1599.000000
# mean     10.422983     5.636023
# std       1.065668     0.807569
# min       8.400000     3.000000
# 25%       9.500000     5.000000
# 50%      10.200000     6.000000
# 75%      11.100000     6.000000
# max      14.900000     8.000000

# %%
# define base model
def baseline_model():
    # create model
    model = Sequential()
    model.add(Conv1D(16, 2, activation="relu", input_shape=(11,1)))
    model.add(Conv1D(12, 2, activation="relu"))
    #model.add(Dense(16, activation="relu"))
    model.add(MaxPooling1D())
    model.add(Flatten())
    #model.add(Dense(8, input_dim=8, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# evaluate model
estimator = KerasRegressor(build_fn=baseline_model, epochs=400, batch_size=5, verbose=1)
kfold = KFold(n_splits=5)
results = cross_val_score(estimator, X, Y, cv=kfold)
print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))
print(results)
# Out:
# <ipython-input-5-84dbecbe6121>:2: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   estimator = KerasRegressor(build_fn=baseline_model, epochs=400, batch_size=5, verbose=1)
# Epoch 1/400
# 256/256 [==============================] - 1s 727us/step - loss: 10.1187
# Epoch 2/400
# 256/256 [==============================] - 0s 741us/step - loss: 1.3764
# Epoch 3/400
# 256/256 [==============================] - 0s 841us/step - loss: 0.9564
# Epoch 4/400
# 256/256 [==============================] - 0s 700us/step - loss: 0.8605
# Epoch 5/400
# 256/256 [==============================] - 0s 810us/step - loss: 0.8238
# Epoch 6/400
# 256/256 [==============================] - 0s 763us/step - loss: 0.7274
# Epoch 7/400
# 256/256 [==============================] - 0s 814us/step - loss: 0.7190
# Epoch 8/400
# 256/256 [==============================] - 0s 762us/step - loss: 0.6923
# Epoch 9/400
# 256/256 [==============================] - 0s 739us/step - loss: 0.6938
# Epoch 10/400
# 256/256 [==============================] - 0s 816us/step - loss: 0.6542
# Epoch 11/400
# 256/256 [==============================] - 0s 781us/step - loss: 0.6223
# Epoch 12/400
# 256/256 [==============================] - 0s 817us/step - loss: 0.6621
# Epoch 13/400
# 256/256 [==============================] - 0s 688us/step - loss: 0.6215
# Epoch 14/400
# 256/256 [==============================] - 0s 681us/step - loss: 0.6391
# Epoch 15/400
# 256/256 [==============================] - 0s 688us/step - loss: 0.6264
# Epoch 16/400
# 256/256 [==============================] - 0s 716us/step - loss: 0.6128
# Epoch 17/400
# 256/256 [==============================] - 0s 817us/step - loss: 0.6112
# Epoch 18/400
# 256/256 [==============================] - 0s 727us/step - loss: 0.5942
# Epoch 19/400
# 256/256 [==============================] - 0s 677us/step - loss: 0.6024
# Epoch 20/400
# 256/256 [==============================] - 0s 731us/step - loss: 0.5996
# Epoch 21/400
# 256/256 [==============================] - 0s 817us/step - loss: 0.6037
# Epoch 22/400
# 256/256 [==============================] - 0s 700us/step - loss: 0.5921
# Epoch 23/400
# 256/256 [==============================] - 0s 681us/step - loss: 0.5898
# Epoch 24/400
# 256/256 [==============================] - 0s 712us/step - loss: 0.5818
# Epoch 25/400
# 256/256 [==============================] - 0s 669us/step - loss: 0.5738
# Epoch 26/400
# 256/256 [==============================] - 0s 681us/step - loss: 0.5705
# Epoch 27/400
# 256/256 [==============================] - 0s 696us/step - loss: 0.5755
# Epoch 28/400
# 256/256 [==============================] - 0s 681us/step - loss: 0.5863
# Epoch 29/400
# 256/256 [==============================] - 0s 700us/step - loss: 0.5879
# Epoch 30/400
# 256/256 [==============================] - 0s 677us/step - loss: 0.5784
# Epoch 31/400
# 256/256 [==============================] - 0s 684us/step - loss: 0.5691
# Epoch 32/400
# 256/256 [==============================] - 0s 683us/step - loss: 0.5705
# Epoch 33/400
# 256/256 [==============================] - 0s 703us/step - loss: 0.5631
# Epoch 34/400
# 256/256 [==============================] - 0s 683us/step - loss: 0.5594
# Epoch 35/400
# 256/256 [==============================] - 0s 753us/step - loss: 0.5686
# Epoch 36/400
# 256/256 [==============================] - 0s 778us/step - loss: 0.5594
# Epoch 37/400
# 256/256 [==============================] - 0s 684us/step - loss: 0.5657
# Epoch 38/400
# 256/256 [==============================] - 0s 696us/step - loss: 0.5685
# Epoch 39/400
# 256/256 [==============================] - 0s 688us/step - loss: 0.5739
# Epoch 40/400
#  76/256 [=======>......................] - ETA: 0s - loss: 0.5160

# %%
# 2nd test ....
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
estimator.fit(X, Y)
prediction = estimator.predict(X)

train_error =  np.abs(Y - prediction)
mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)
print('\nTraining results:\nmean=',mean_error,'\nmin=',min_error,'\nmax=',max_error,'\nstd=',std_error)

# %%
df = pd.DataFrame({'Actual': Y, 'Predicted': prediction})
df1 = df.tail(25)
print(df1)

# %%
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.plot(train_error,'r.')
plt.ylabel('train error')
plt.show()

# %%
estimator.fit(X_train, Y_train)
prediction = estimator.predict(X_test)

test_error =  np.abs(Y_test - prediction)
mean_error = np.mean(test_error)
min_error = np.min(test_error)
max_error = np.max(test_error)
std_error = np.std(test_error)
print('\nTesting results:\nmean=',mean_error,'\nmin=',min_error,'\nmax=',max_error,'\nstd=',std_error)

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': prediction})
df1 = df.tail(25)
print(df1)

# %%
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.plot(test_error,'r.')
plt.ylabel('test error')
plt.show()
