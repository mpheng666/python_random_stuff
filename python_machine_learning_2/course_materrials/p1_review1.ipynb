# %% [markdown]
# # Python Intro Example 1

# %%
#importing Counter from collections
from collections import Counter

numbers = [4,5,5,2,22,2,2,1,8,9,7,7]
num_counter = Counter(numbers)
print(num_counter)
# Out:
# Counter({2: 3, 5: 2, 7: 2, 4: 1, 22: 1, 1: 1, 8: 1, 9: 1})

# %%
#counter with strings
string = 'lalalalandismagic'
string_count = Counter(string)
print(string_count)
# Out:
# Counter({'a': 5, 'l': 4, 'i': 2, 'n': 1, 'd': 1, 's': 1, 'm': 1, 'g': 1, 'c': 1})

# %%
# Using counter on sentences
line = 'he told her that her presentation was not that good'

list_of_words = line.split() 
line_count=Counter(list_of_words)
print(line_count)
# Out:
# Counter({'her': 2, 'that': 2, 'he': 1, 'told': 1, 'presentation': 1, 'was': 1, 'not': 1, 'good': 1})

# %%
s = 'ba'
t = s * 2 # create 2 copies of s
print(t)

'ab' in t #
# Out:
# baba
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'ab' in t
# Out:
# True

# %%
# Excersise: What is w?
w = (s+'@')*2 
# then what is w?
w += ' , 2 , 2'
w
# Out:
# 'ba@ba@ , 2 , 2'

# %%
# Passing different values of n to most_common() function
print('The 2 most common elements in `numbers` are', Counter(numbers).most_common(2))
print('The 3 most common elements in `string` are', Counter(string).most_common(3))
# Out:
# The 2 most common elements in `numbers` are [(2, 3), (5, 2)]
# The 3 most common elements in `string` are [('a', 5), ('l', 4), ('i', 2)]

# %%
code = int( input('Enter a 6-digit ZIP code: ') )
digit = code // 100000  # extract first digit
if (digit>0 and digit<=3):
    print(code, 'is on the East Coast.')
elif (digit>0 and digit<=6): 
    print(code, 'is in the Central Plains.')
elif (digit == 7):
    print(code, 'is in the South.')
else: # digit==8 or digit==9
    print(code, 'is in the West.')
# Out:
# Enter a 6-digit ZIP code: -1234234
# -1234234 is in the West.

# %% [markdown]
# ## Practice: Make it right please !!!

# %% [markdown]
# ## Data Collection Provided by Python
# •
# Immutable Sequence
# • tuple
# •
# Mutable Sequence
# • list
# •
# Non-indexed Collection
# • dictionary, set

# %%
# Tuples
t1 = (1, 2, 3)
t2 = ('a', 'b', 'c')
t3 = (t1, t2)
t3
# Out:
# ((1, 2, 3), ('a', 'b', 'c'))

# %%
b = [5, 2, 7, 4]
min(b) , sum(b)
# Out:
# (2, 18)

# %%
lst = [1, 2, 3]
lst[0] = 5
lst[-1] = 0
print(lst)
# Out:
# [5, 2, 0]

# %%
lst = [1, 2, 3]
lst.append(5)
print(lst)

lst = [1, 2, 6.5, 'good', False]
del  lst[0]
print(lst)
del  lst[2:4]
print(lst) 

lst = [1, 2, 3]
lst.extend([4, 5])
# lst = [1, 2, 3]
# concatenation
# a new list created!
lst= lst+ [4, 5]
lst
# Out:
# [1, 2, 3, 5]
# [2, 6.5, 'good', False]
# [2, 6.5]
# [1, 2, 3, 4, 5, 4, 5]

# %%
lst1 = [1, 2, 3]
lst2 = [4, 5]

## WATCH OUT THE ALIASING!! WHY NUMPY AND PANDAS SHOULD BE USED INSTEAD!
lst1.append(lst2)
print(lst1)
# trace the following!
lst2[0] = 8
lst1[3][1] = 9
print(lst1)
# Out:
# [1, 2, 3, [4, 5]]
# [1, 2, 3, [8, 9]]

# %%
a = [1, 2, 3, -4, 5.1, -6.3]
b = [ x for x in a if x%2 == 0 ]
print(b)
b = [ x**2 for x in a if x%2 == 0 ]
print(b)
# Out:
# [2, -4]
# [4, 16]

# %%
# SETS 
s = { 1, 2, 3, 4, 5, 3, 1, 2 }

print(s)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
setA = {1, 2, 3}
setB= {3, 4, 5}
print( setA | setB) # set union
print( setA & setB) # set intersection
print( setA -setB) # difference
print( setA ^ setB) # symmetricdifference
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {1, 2, 4, 5}

# %%
# Dictionary
stock ={ # stock of fruits
    'apple': 450,
    'orange': 412,
    'kiwi': 100,
}
stock['apple'] = 500# key exists, update value!
stock['strawberry'] = 20# add a new key:valuepair
print(stock)
# Out:
# {'apple': 500, 'orange': 412, 'kiwi': 100, 'strawberry': 20}

# %%
del stock['apple']# delete an entry (key:value)
print(stock)
stock.clear()# delete all entries
print(stock)
# Out:
# {'orange': 412, 'kiwi': 100, 'strawberry': 20}
# {}

# %%
stock ={ # stock of fruits
'apple': 450,
'orange': 412,
'kiwi': 100,
}
for key in stock:
    print(stock[key])
print('====================')
for key, value in stock.items():
    print(key, ':', value)
# Out:
# 450
# 412
# 100
# ...
# apple : 450
# orange : 412
# kiwi : 100

# %% [markdown]
# # Exercise 1:
#   develop a program to ask you as the user to consider an integer number between 0 and 100,
#     then computer should ask you a series of questions and finding that number by dividing the ranges by 2.
#     e.g., is it bigger than 50? etc.....

# %%
result = 50
upperb = 101
lowerb = -1
answer = 0
correct = 0
while(not correct and result != 0):
    string_1 = "\nEnter 1 (yes), 0 (no) \n"

    string_2 = "Is the number equal to " + str(result) + string_1
    correct = int(input(string_2))
    if(correct):
        break    
    
    string_3 = "Is the number bigger than " + str(result) + string_1
    answer = int(input(string_3))
    if(not answer):
        upperb = min(upperb, result)
        result = result - (result - lowerb)//2
    else:
        lowerb = max(lowerb, result)
        result = result + (upperb - result)//2
        
print("The correct number is ", result, "!")
# Out:
# Is the number bigger than 50
# Enter 1 (yes), 0 (no)
# 0
# Is the number bigger than 25
# Enter 1 (yes), 0 (no)
# 0
# Is the number bigger than 12
# Enter 1 (yes), 0 (no)
# 1
# Is the number bigger than 18
# Enter 1 (yes), 0 (no)
# 1
# Is the number bigger than 21
# Enter 1 (yes), 0 (no)
# 1
# Is the number bigger than 23
# Enter 1 (yes), 0 (no)
# 0
# Is the number bigger than 22
# Enter 1 (yes), 0 (no)
# 1
# Is the number bigger than 22
# Enter 1 (yes), 0 (no)
# 1
# Is the number bigger than 22
# Enter 1 (yes), 0 (no)
# 0
# The correct number is  22 !

# %% [markdown]
# # Exercise 2:
#   develop a program to read the area of a circle from the input, compute the radius of that circle, and print it nicely, then read the area of the next circle and continue till the entered area is a negative number

# %%
import math
# Ask for area input the first time
area = float( input('Enter area of a circle: ') )

# while input is not negative
while(area>0):

    # Calculate the radius | area = pi * r * r | r = sqrt(area/pi)
    radius = math.sqrt(area/3.142)
    print("The radius is ", radius, "\n")
    area = float( input('Enter area of a circle: ') )
# Out:
# Enter area of a circle: 123
# The radius is  6.256759552823327
#
# Enter area of a circle: 32
# The radius is  3.1913313520933912
#
# Enter area of a circle: 123
# The radius is  6.256759552823327
#
# Enter area of a circle: 435
# The radius is  11.766343915621146
#
# Enter area of a circle: -234

# %% [markdown]
# ### Complete this notebook and submit/upload it before the deadline to Luminuns / files / Coursework Submission directory ...
