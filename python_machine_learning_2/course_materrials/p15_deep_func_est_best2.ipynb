# %% [markdown]
# # Deep Learning for Function Estimation

# %%
# CNN version
# Regression Example With wine dataset ...
# !pip install tensorflow
import pandas as pd
from pandas import read_csv
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense 
from tensorflow.keras.layers import Conv1D 
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split 
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: tensorflow in /home/mpheng/anaconda3/lib/python3.9/site-packages (2.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: libclang>=13.0.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: six>=1.12.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: numpy>=1.20 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: h5py>=2.9.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: setuptools in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (61.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: packaging in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: absl-py>=1.0.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (22.9.24)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.27.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.33.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/mpheng/anaconda3/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.4)

# %%
# load dataset
dataframe = read_csv("wine_r2_t_noheader.csv" , header=None)
dataset = dataframe.values

# split into input (X) and output (Y) variables
X = dataset[:,0:11]
Y = dataset[:,11]

print(X.shape)
X = X.reshape(X.shape[0], X.shape[1], 1)
print(X.shape)
# Out:
# (1599, 11)
# (1599, 11, 1)

# %%
print(dataset.shape)
dataframe.describe()
# Out:
# (1599, 12)
#                 0            1            2            3            4   \
# count  1599.000000  1599.000000  1599.000000  1599.000000  1599.000000
# mean      8.319637     0.527821     0.270976     2.538806     0.087467
# std       1.741096     0.179060     0.194801     1.409928     0.047065
# min       4.600000     0.120000     0.000000     0.900000     0.012000
# 25%       7.100000     0.390000     0.090000     1.900000     0.070000
# 50%       7.900000     0.520000     0.260000     2.200000     0.079000
# 75%       9.200000     0.640000     0.420000     2.600000     0.090000
# max      15.900000     1.580000     1.000000    15.500000     0.611000
#
#                 5            6            7            8            9   \
# count  1599.000000  1599.000000  1599.000000  1599.000000  1599.000000
# mean     15.874922    46.467792     0.996747     3.311113     0.658149
# std      10.460157    32.895324     0.001887     0.154386     0.169507
# min       1.000000     6.000000     0.990070     2.740000     0.330000
# 25%       7.000000    22.000000     0.995600     3.210000     0.550000
# 50%      14.000000    38.000000     0.996750     3.310000     0.620000
# 75%      21.000000    62.000000     0.997835     3.400000     0.730000
# max      72.000000   289.000000     1.003690     4.010000     2.000000
#
#                 10           11
# count  1599.000000  1599.000000
# mean     10.422983     5.636023
# std       1.065668     0.807569
# min       8.400000     3.000000
# 25%       9.500000     5.000000
# 50%      10.200000     6.000000
# 75%      11.100000     6.000000
# max      14.900000     8.000000

# %%
# define base model
def baseline_model():
    # create model
    model = Sequential()
    model.add(Conv1D(24, 2, activation="relu", input_shape=(11,1)))
    model.add(MaxPooling1D())
    model.add(Conv1D(6, 2, activation="relu"))
    model.add(MaxPooling1D())
    model.add(Conv1D(12, 2, activation="relu"))
    model.add(MaxPooling1D())
    model.add(Flatten())
    model.add(Dense(1, kernel_initializer='normal'))
    
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# evaluate model
estimator = KerasRegressor(build_fn=baseline_model, epochs=400, batch_size=5, verbose=1)
kfold = KFold(n_splits=5)
results = cross_val_score(estimator, X, Y, cv=kfold)
print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))
print(results)
# Out:
# /tmp/ipykernel_623/383927505.py:2: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   estimator = KerasRegressor(build_fn=baseline_model, epochs=400, batch_size=5, verbose=1)
# Baseline: nan (nan) MSE
# [nan nan nan nan nan]
# /home/mpheng/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_623/3635701473.py", line 10, in baseline_model
#     model.add(MaxPooling1D())
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/tensorflow/python/trackable/base.py", line 205, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/backend.py", line 6493, in pool2d
#     x = tf.compat.v1.nn.max_pool(
# ValueError: Exception encountered when calling layer "max_pooling1d_38" (type MaxPooling1D).
#
# Negative dimension size caused by subtracting 2 from 1 for '{{node max_pooling1d_38/MaxPool}} = MaxPool[T=DT_FLOAT, data_format="NHWC", explicit_paddings=[], ksize=[1, 2, 1, 1], padding="VALID", strides=[1, 2, 1, 1]](max_pooling1d_38/ExpandDims)' with input shapes: [?,1,1,12].
#
# Call arguments received by layer "max_pooling1d_38" (type MaxPooling1D):
#   • inputs=tf.Tensor(shape=(None, 1, 12), dtype=float32)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_623/3635701473.py", line 10, in baseline_model
#     model.add(MaxPooling1D())
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/tensorflow/python/trackable/base.py", line 205, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/backend.py", line 6493, in pool2d
#     x = tf.compat.v1.nn.max_pool(
# ValueError: Exception encountered when calling layer "max_pooling1d_41" (type MaxPooling1D).
#
# Negative dimension size caused by subtracting 2 from 1 for '{{node max_pooling1d_41/MaxPool}} = MaxPool[T=DT_FLOAT, data_format="NHWC", explicit_paddings=[], ksize=[1, 2, 1, 1], padding="VALID", strides=[1, 2, 1, 1]](max_pooling1d_41/ExpandDims)' with input shapes: [?,1,1,12].
#
# Call arguments received by layer "max_pooling1d_41" (type MaxPooling1D):
#   • inputs=tf.Tensor(shape=(None, 1, 12), dtype=float32)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_623/3635701473.py", line 10, in baseline_model
#     model.add(MaxPooling1D())
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/tensorflow/python/trackable/base.py", line 205, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/backend.py", line 6493, in pool2d
#     x = tf.compat.v1.nn.max_pool(
# ValueError: Exception encountered when calling layer "max_pooling1d_44" (type MaxPooling1D).
#
# Negative dimension size caused by subtracting 2 from 1 for '{{node max_pooling1d_44/MaxPool}} = MaxPool[T=DT_FLOAT, data_format="NHWC", explicit_paddings=[], ksize=[1, 2, 1, 1], padding="VALID", strides=[1, 2, 1, 1]](max_pooling1d_44/ExpandDims)' with input shapes: [?,1,1,12].
#
# Call arguments received by layer "max_pooling1d_44" (type MaxPooling1D):
#   • inputs=tf.Tensor(shape=(None, 1, 12), dtype=float32)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_623/3635701473.py", line 10, in baseline_model
#     model.add(MaxPooling1D())
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/tensorflow/python/trackable/base.py", line 205, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/backend.py", line 6493, in pool2d
#     x = tf.compat.v1.nn.max_pool(
# ValueError: Exception encountered when calling layer "max_pooling1d_47" (type MaxPooling1D).
#
# Negative dimension size caused by subtracting 2 from 1 for '{{node max_pooling1d_47/MaxPool}} = MaxPool[T=DT_FLOAT, data_format="NHWC", explicit_paddings=[], ksize=[1, 2, 1, 1], padding="VALID", strides=[1, 2, 1, 1]](max_pooling1d_47/ExpandDims)' with input shapes: [?,1,1,12].
#
# Call arguments received by layer "max_pooling1d_47" (type MaxPooling1D):
#   • inputs=tf.Tensor(shape=(None, 1, 12), dtype=float32)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "/tmp/ipykernel_623/3635701473.py", line 10, in baseline_model
#     model.add(MaxPooling1D())
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/tensorflow/python/trackable/base.py", line 205, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/home/mpheng/anaconda3/lib/python3.9/site-packages/keras/backend.py", line 6493, in pool2d
#     x = tf.compat.v1.nn.max_pool(
# ValueError: Exception encountered when calling layer "max_pooling1d_50" (type MaxPooling1D).
#
# Negative dimension size caused by subtracting 2 from 1 for '{{node max_pooling1d_50/MaxPool}} = MaxPool[T=DT_FLOAT, data_format="NHWC", explicit_paddings=[], ksize=[1, 2, 1, 1], padding="VALID", strides=[1, 2, 1, 1]](max_pooling1d_50/ExpandDims)' with input shapes: [?,1,1,12].
#
# Call arguments received by layer "max_pooling1d_50" (type MaxPooling1D):
#   • inputs=tf.Tensor(shape=(None, 1, 12), dtype=float32)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %%
# 2nd test ....
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
estimator.fit(X, Y)
prediction = estimator.predict(X)

train_error =  np.abs(Y - prediction)
mean_error = np.mean(train_error)
min_error = np.min(train_error)
max_error = np.max(train_error)
std_error = np.std(train_error)
print('\nTraining results:\nmean=',mean_error,'\nmin=',min_error,'\nmax=',max_error,'\nstd=',std_error)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 estimator.fit(X, Y)
#       2 prediction = estimator.predict(X)
#       4 train_error =  np.abs(Y - prediction)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py:164, in BaseWrapper.fit(self, x, y, **kwargs)
#     160     self.model = self.build_fn(
#     161         **self.filter_sk_params(self.build_fn.__call__)
#     162     )
#     163 else:
# --> 164     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#     166 if (
#     167     losses.is_categorical_crossentropy(self.model.loss)
#     168     and len(y.shape) != 2
#     169 ):
#     170     y = to_categorical(y)
#
# Input In [5], in baseline_model()
#       8 model.add(MaxPooling1D())
#       9 model.add(Conv1D(12, 2, activation="relu"))
# ---> 10 model.add(MaxPooling1D())
#      11 model.add(Flatten())
#      12 model.add(Dense(1, kernel_initializer='normal'))
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/trackable/base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/backend.py:6493, in pool2d(x, pool_size, strides, padding, data_format, pool_mode)
#    6490     pool_size = (1, 1) + pool_size
#    6492 if pool_mode == "max":
# -> 6493     x = tf.compat.v1.nn.max_pool(
#    6494         x, pool_size, strides, padding=padding, data_format=tf_data_format
#    6495     )
#    6496 elif pool_mode == "avg":
#    6497     x = tf.compat.v1.nn.avg_pool(
#    6498         x, pool_size, strides, padding=padding, data_format=tf_data_format
#    6499     )
#
# ValueError: Exception encountered when calling layer "max_pooling1d_17" (type MaxPooling1D).
#
# Negative dimension size caused by subtracting 2 from 1 for '{{node max_pooling1d_17/MaxPool}} = MaxPool[T=DT_FLOAT, data_format="NHWC", explicit_paddings=[], ksize=[1, 2, 1, 1], padding="VALID", strides=[1, 2, 1, 1]](max_pooling1d_17/ExpandDims)' with input shapes: [?,1,1,12].
#
# Call arguments received by layer "max_pooling1d_17" (type MaxPooling1D):
#   • inputs=tf.Tensor(shape=(None, 1, 12), dtype=float32)

# %%
df = pd.DataFrame({'Actual': Y, 'Predicted': prediction})
df1 = df.tail(25)
print(df1)

# %%
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.plot(train_error,'r.')
plt.ylabel('train error')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 plt.plot(train_error,'r.')
#       2 plt.ylabel('train error')
#       3 plt.show()
#
# NameError: name 'train_error' is not defined

# %%
estimator.fit(X_train, Y_train)
prediction = estimator.predict(X_test)

test_error =  np.abs(Y_test - prediction)
mean_error = np.mean(test_error)
min_error = np.min(test_error)
max_error = np.max(test_error)
std_error = np.std(test_error)
print('\nTesting results:\nmean=',mean_error,'\nmin=',min_error,'\nmax=',max_error,'\nstd=',std_error)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 estimator.fit(X_train, Y_train)
#       2 prediction = estimator.predict(X_test)
#       4 test_error =  np.abs(Y_test - prediction)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py:164, in BaseWrapper.fit(self, x, y, **kwargs)
#     160     self.model = self.build_fn(
#     161         **self.filter_sk_params(self.build_fn.__call__)
#     162     )
#     163 else:
# --> 164     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#     166 if (
#     167     losses.is_categorical_crossentropy(self.model.loss)
#     168     and len(y.shape) != 2
#     169 ):
#     170     y = to_categorical(y)
#
# Input In [5], in baseline_model()
#       8 model.add(MaxPooling1D())
#       9 model.add(Conv1D(12, 2, activation="relu"))
# ---> 10 model.add(MaxPooling1D())
#      11 model.add(Flatten())
#      12 model.add(Dense(1, kernel_initializer='normal'))
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/trackable/base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/backend.py:6493, in pool2d(x, pool_size, strides, padding, data_format, pool_mode)
#    6490     pool_size = (1, 1) + pool_size
#    6492 if pool_mode == "max":
# -> 6493     x = tf.compat.v1.nn.max_pool(
#    6494         x, pool_size, strides, padding=padding, data_format=tf_data_format
#    6495     )
#    6496 elif pool_mode == "avg":
#    6497     x = tf.compat.v1.nn.avg_pool(
#    6498         x, pool_size, strides, padding=padding, data_format=tf_data_format
#    6499     )
#
# ValueError: Exception encountered when calling layer "max_pooling1d_20" (type MaxPooling1D).
#
# Negative dimension size caused by subtracting 2 from 1 for '{{node max_pooling1d_20/MaxPool}} = MaxPool[T=DT_FLOAT, data_format="NHWC", explicit_paddings=[], ksize=[1, 2, 1, 1], padding="VALID", strides=[1, 2, 1, 1]](max_pooling1d_20/ExpandDims)' with input shapes: [?,1,1,12].
#
# Call arguments received by layer "max_pooling1d_20" (type MaxPooling1D):
#   • inputs=tf.Tensor(shape=(None, 1, 12), dtype=float32)

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': prediction})
df1 = df.tail(25)
print(df1)

# %%
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.plot(test_error,'r.')
plt.ylabel('test error')
plt.show()

# %%
test_error2 =  np.abs(Y_test - np.round(prediction) )
mean_error2 = np.mean(test_error2)
min_error2 = np.min(test_error2)
max_error2 = np.max(test_error2)
std_error2 = np.std(test_error2)
print('\nTesting results:\nmean=',mean_error2,'\nmin=',min_error2,'\nmax=',max_error2,'\nstd=',std_error2 )

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': np.round(prediction)})
df1 = df.tail(25)
print(df1)

df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.plot(test_error2,'r.')
plt.ylabel('test error rounded')
plt.show()
